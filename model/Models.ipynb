# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.optimizers import RMSprop
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import VGG16
from glob import glob
from keras.models import Model
from keras.layers import Flatten, Dense
from sklearn.metrics import classification_report, confusion_matrix
from keras.applications import ResNet50V2, MobileNetV2, InceptionV3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install rembg[gpu]
from rembg import remove
output = ["BGR","ORG","Crop"]

# %%
# Changable parameters
mode = "Crop"
IMAGE_HEIGHT_WIDTH = 350

# %%
if (mode == "BGR"):
#Training set background removal

  directory1 ='/content/drive/MyDrive/Projects/GP Project/Dataset/TrainSet'
  new_created1 = '/content/drive/MyDrive/Projects/GP Project/Dataset/BgRemoved/Training'

  for filename in glob(f'{directory1}/*'):
    folder = os.path.basename(filename)
    try:
      path1 = os.path.join(new_created1, folder)
      os.makedirs(path1)  
      for image in glob(f'{filename}/*'):
          image_extend = os.path.basename(image)
          input_path = image
          output_path = os.path.join(path1, image_extend)
          input = Image.open(input_path)
          output = remove(input)
          output.save(output_path)
    except FileExistsError:
      # directory already exists
      pass

#validition set background removal
  directory2 ='/content/drive/MyDrive/Projects/GP Project/Dataset/ValidationSet'
  new_created2 = '/content/drive/MyDrive/Projects/GP Project/Dataset/BgRemoved/Validation'

  for filename in glob(f'{directory2}/*'):
    folder = os.path.basename(filename)
    try:
      path2 = os.path.join(new_created2, folder)
      os.makedirs(path2)  
      for image in glob(f'{filename}/*'):
          image_extend = os.path.basename(image)
          input_path = image
          output_path = os.path.join(path2, image_extend)
          input = Image.open(input_path)
          output = remove(input)
          output.save(output_path)
    except FileExistsError:
      # directory already exists
      pass

#validition set background removal
  directory3 ='/content/drive/MyDrive/Projects/GP Project/Dataset/TestSet'
  new_created3 = '/content/drive/MyDrive/Projects/GP Project/Dataset/BgRemoved/Testing'

  try:  
    os.makedirs(new_created3)  
    for image in glob("/content/drive/MyDrive/Projects/GP Project/Dataset/TestSet/*.png"):
        image_extend = os.path.basename(image)
        input_path = image
        output_path = os.path.join(new_created3, image_extend)
        input = Image.open(input_path)
        output = remove(input)
        output.save(output_path)
  except FileExistsError:
    # directory already exists
    pass

else: pass

# %%
train = ImageDataGenerator(rescale = 1./255)
validation = ImageDataGenerator(rescale = 1./255)
#train = ImageDataGenerator()
#validation = ImageDataGenerator()
if (mode == "ORG"):
  #training and validation with the original dataset
  train_dataset = train.flow_from_directory('/content/drive/MyDrive/Projects/GP Project/Dataset/TrainSet',
                                          target_size = (IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH),
                                          batch_size = 32,
                                          class_mode = "categorical")
  validation_dataset = validation.flow_from_directory('/content/drive/MyDrive/Projects/GP Project/Dataset/ValidationSet',
                                                    target_size = (IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH),
                                                    batch_size = 32,
                                                    class_mode = "categorical")
elif mode == "Crop":
    #training and validation with the cropped dataset
  train_dataset = train.flow_from_directory('/content/drive/MyDrive/Projects/GP Project/Dataset/croppedDataset/trainSet',
                                          target_size = (IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH),
                                          batch_size = 25,
                                          class_mode = "categorical")
  validation_dataset = validation.flow_from_directory('/content/drive/MyDrive/Projects/GP Project/Dataset/croppedDataset/validSet',
                                                    target_size = (IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH),
                                                    batch_size = 25,
                                                    class_mode = "categorical")
else:
  #training and validation with the background removal dataset
  train_dataset = train.flow_from_directory('/content/drive/MyDrive/Projects/GP Project/Dataset/BgRemoved/Training',
                                          target_size = (IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH),
                                          batch_size = 32,
                                          class_mode = "categorical")
  validation_dataset = validation.flow_from_directory('/content/drive/MyDrive/Projects/GP Project/Dataset/BgRemoved/Validation',
                                                    target_size = (IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH),
                                                    batch_size = 32,
                                                    class_mode = "categorical")
# Out:
# Found 140 images belonging to 7 classes.
# Found 31 images belonging to 7 classes.

# %%
train_dataset.class_indices
my_dic = dict(train_dataset.class_indices)
my_dic
# Out:
# {'bed': 0,
#  'father': 1,
#  'full': 2,
#  'police': 3,
#  'shirt': 4,
#  'water': 5,
#  'wrong': 6}

# %%
if mode == "Crop":
  # useful for getting number of classes
  folders = glob('/content/drive/MyDrive/Projects/GP Project/Dataset/croppedDataset/validSet/*')
elif mode == "ORG":
  folders = glob('/content/drive/MyDrive/Projects/GP Project/Dataset/ValidationSet/*')
else:
  folders = glob('/content/drive/MyDrive/Projects/GP Project/Dataset/BgRemoved/Validation/*')

# %% [markdown]
# # Model 1 VGG16

# %%
vgg = VGG16(input_shape=(IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH,3), weights='imagenet', include_top=False)

# don't train existing weights
for layer in vgg.layers:
  layer.trainable = False
  
# our layers - you can add more if you want
x = Flatten()(vgg.output)
# x = Dense(1000, activation='relu')(x)
prediction = Dense(len(folders), activation='softmax')(x)

# create a model object
model = Model(inputs=vgg.input, outputs=prediction)

# view the structure of the model
model.summary()

# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 350, 350, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 350, 350, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 350, 350, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 175, 175, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 175, 175, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 175, 175, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 87, 87, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 87, 87, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 87, 87, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 87, 87, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 43, 43, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 43, 43, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 43, 43, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 43, 43, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 21, 21, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 21, 21, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 21, 21, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 21, 21, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 10, 10, 512)       0
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 7)                 358407
#
# =================================================================
# Total params: 15,073,095
# Trainable params: 358,407
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
hist = model.fit_generator(steps_per_epoch=len(train_dataset), generator=train_dataset, validation_data=validation_dataset, validation_steps=len(validation_dataset), epochs=6, callbacks=[checkpoint,early])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# <ipython-input-10-bca8a532f54f>:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(steps_per_epoch=len(train_dataset), generator=train_dataset, validation_data=validation_dataset, validation_steps=len(validation_dataset), epochs=6, callbacks=[checkpoint,early])
# Epoch 1/6
# 6/6 [==============================] - ETA: 0s - loss: 1.7329 - accuracy: 0.4571
# Epoch 1: val_accuracy improved from -inf to 0.74194, saving model to vgg16_1.h5
# 6/6 [==============================] - 17s 2s/step - loss: 1.7329 - accuracy: 0.4571 - val_loss: 0.9218 - val_accuracy: 0.7419
# Epoch 2/6
# 6/6 [==============================] - ETA: 0s - loss: 0.3517 - accuracy: 0.8714
# Epoch 2: val_accuracy improved from 0.74194 to 0.77419, saving model to vgg16_1.h5
# 6/6 [==============================] - 3s 452ms/step - loss: 0.3517 - accuracy: 0.8714 - val_loss: 0.7138 - val_accuracy: 0.7742
# Epoch 3/6
# 6/6 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9929
# Epoch 3: val_accuracy did not improve from 0.77419
# 6/6 [==============================] - 2s 443ms/step - loss: 0.0540 - accuracy: 0.9929 - val_loss: 0.6673 - val_accuracy: 0.7419
# Epoch 4/6
# 6/6 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9929
# Epoch 4: val_accuracy did not improve from 0.77419
# 6/6 [==============================] - 3s 417ms/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.7539 - val_accuracy: 0.7742
# Epoch 5/6
# 6/6 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 1.0000
# Epoch 5: val_accuracy did not improve from 0.77419
# 6/6 [==============================] - 3s 414ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.8135 - val_accuracy: 0.7419
# Epoch 6/6
# 6/6 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 6: val_accuracy improved from 0.77419 to 0.80645, saving model to vgg16_1.h5
# 6/6 [==============================] - 3s 444ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.6736 - val_accuracy: 0.8065

# %% [markdown]
# # Model 2 from Related work

# %% [markdown]
# ## Model 2.1 "It was said that this model was overfitting"

# %%
model2_1 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(filters=10, 
                         kernel_size=3, # can also be (3, 3)
                         activation="relu", 
                         input_shape=(IMAGE_HEIGHT_WIDTH, IMAGE_HEIGHT_WIDTH, 3)), # first layer specifies input shape (height, width, colour channels)
  tf.keras.layers.MaxPool2D(pool_size=2, # pool_size can also be (2, 2)
                            padding="valid"), # padding can also be 'same'
  tf.keras.layers.Conv2D(filters=10, 
                         kernel_size=3, 
                         activation="relu"
                         ),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(len(folders), activation="softmax") # binary activation output
])
model2_1.summary()

# Compile the model
model2_1.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 348, 348, 10)      280
#
#  max_pooling2d (MaxPooling2D  (None, 174, 174, 10)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 172, 172, 10)      910
#
#  flatten_1 (Flatten)         (None, 295840)            0
#
#  dense_1 (Dense)             (None, 7)                 2070887
#
# =================================================================
# Total params: 2,072,077
# Trainable params: 2,072,077
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_1 = model2_1.fit(train_dataset,
                        epochs=20,
                        steps_per_epoch=len(train_dataset),
                        validation_data=validation_dataset,
                        validation_steps=len(validation_dataset))
# Out:
# Epoch 1/20
# 6/6 [==============================] - 2s 242ms/step - loss: 21.0278 - accuracy: 0.1786 - val_loss: 7.8192 - val_accuracy: 0.2258
# Epoch 2/20
# 6/6 [==============================] - 1s 152ms/step - loss: 5.4481 - accuracy: 0.3429 - val_loss: 2.5965 - val_accuracy: 0.4516
# Epoch 3/20
# 6/6 [==============================] - 1s 149ms/step - loss: 1.4692 - accuracy: 0.6214 - val_loss: 1.7125 - val_accuracy: 0.3226
# Epoch 4/20
# 6/6 [==============================] - 1s 149ms/step - loss: 1.0056 - accuracy: 0.7929 - val_loss: 1.8583 - val_accuracy: 0.2581
# Epoch 5/20
# 6/6 [==============================] - 1s 147ms/step - loss: 0.7537 - accuracy: 0.8714 - val_loss: 1.4549 - val_accuracy: 0.4516
# Epoch 6/20
# 6/6 [==============================] - 1s 146ms/step - loss: 0.3956 - accuracy: 0.9857 - val_loss: 1.3280 - val_accuracy: 0.5484
# Epoch 7/20
# 6/6 [==============================] - 1s 153ms/step - loss: 0.1846 - accuracy: 0.9857 - val_loss: 1.2895 - val_accuracy: 0.5484
# Epoch 8/20
# 6/6 [==============================] - 1s 154ms/step - loss: 0.0997 - accuracy: 1.0000 - val_loss: 1.3032 - val_accuracy: 0.5161
# Epoch 9/20
# 6/6 [==============================] - 1s 152ms/step - loss: 0.0552 - accuracy: 0.9929 - val_loss: 1.3133 - val_accuracy: 0.5161
# Epoch 10/20
# 6/6 [==============================] - 1s 154ms/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 1.8381 - val_accuracy: 0.3548
# Epoch 11/20
# 6/6 [==============================] - 1s 153ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 1.4510 - val_accuracy: 0.4839
# Epoch 12/20
# 6/6 [==============================] - 1s 144ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.6717 - val_accuracy: 0.4516
# Epoch 13/20
# 6/6 [==============================] - 1s 146ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.9832 - val_accuracy: 0.3548
# Epoch 14/20
# 6/6 [==============================] - 1s 158ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7170 - val_accuracy: 0.3871
# Epoch 15/20
# 6/6 [==============================] - 1s 147ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.5815 - val_accuracy: 0.4516
# Epoch 16/20
# 6/6 [==============================] - 1s 145ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.5612 - val_accuracy: 0.4516
# Epoch 17/20
# 6/6 [==============================] - 1s 153ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.5816 - val_accuracy: 0.4516
# Epoch 18/20
# 6/6 [==============================] - 1s 159ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.6386 - val_accuracy: 0.4516
# Epoch 19/20
# 6/6 [==============================] - 1s 146ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.6970 - val_accuracy: 0.4516
# Epoch 20/20
# 6/6 [==============================] - 1s 152ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.7708 - val_accuracy: 0.4516

# %%
model2_1.save('Model2.1_Related_cropped.h5')

# %% [markdown]
# ## Model 2.2

# %%
model2_2 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(filters=32, 
                         kernel_size=3, 
                         activation="relu", 
                         input_shape=(IMAGE_HEIGHT_WIDTH, IMAGE_HEIGHT_WIDTH, 3)), 
  tf.keras.layers.Conv2D(64, 3, activation="relu"),
  tf.keras.layers.MaxPool2D(pool_size=2, # pool_size can also be (2, 2)
                            padding="valid"), # padding can also be 'same'
  tf.keras.layers.Conv2D(128, 3, activation="relu"),
  tf.keras.layers.Conv2D(32, 3, activation="relu"), # activation='relu' == tf.keras.layers.Activations(tf.nn.relu)
  tf.keras.layers.MaxPool2D(2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(len(folders), activation="softmax") # binary activation output
])

model2_2.summary()
# Compile the model
model2_2.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 348, 348, 32)      896
#
#  conv2d_3 (Conv2D)           (None, 346, 346, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 173, 173, 64)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 171, 171, 128)     73856
#
#  conv2d_5 (Conv2D)           (None, 169, 169, 32)      36896
#
#  max_pooling2d_2 (MaxPooling  (None, 84, 84, 32)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 225792)            0
#
#  dense_2 (Dense)             (None, 7)                 1580551
#
# =================================================================
# Total params: 1,710,695
# Trainable params: 1,710,695
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
history_2 = model2_2.fit(train_dataset,
                        epochs=40,
                        steps_per_epoch=len(train_dataset),
                        validation_data=validation_dataset,
                        validation_steps=len(validation_dataset))
# Out:
# Epoch 1/40
# 6/6 [==============================] - 9s 975ms/step - loss: 2.2360 - accuracy: 0.1714 - val_loss: 1.7810 - val_accuracy: 0.1613
# Epoch 2/40
# 6/6 [==============================] - 2s 352ms/step - loss: 1.2549 - accuracy: 0.5571 - val_loss: 1.8279 - val_accuracy: 0.4194
# Epoch 3/40
# 6/6 [==============================] - 2s 318ms/step - loss: 0.5755 - accuracy: 0.8286 - val_loss: 2.2981 - val_accuracy: 0.4839
# Epoch 4/40
# 6/6 [==============================] - 2s 337ms/step - loss: 0.0900 - accuracy: 0.9714 - val_loss: 3.5760 - val_accuracy: 0.5484
# Epoch 5/40
# 6/6 [==============================] - 2s 310ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 5.3509 - val_accuracy: 0.5161
# Epoch 6/40
# 6/6 [==============================] - 2s 314ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.7729 - val_accuracy: 0.4516
# Epoch 7/40
# 6/6 [==============================] - 2s 335ms/step - loss: 9.3866e-05 - accuracy: 1.0000 - val_loss: 8.0423 - val_accuracy: 0.4516
# Epoch 8/40
# 6/6 [==============================] - 2s 315ms/step - loss: 2.9270e-05 - accuracy: 1.0000 - val_loss: 8.9554 - val_accuracy: 0.4516
# Epoch 9/40
# 6/6 [==============================] - 2s 318ms/step - loss: 1.3542e-05 - accuracy: 1.0000 - val_loss: 9.5552 - val_accuracy: 0.4516
# Epoch 10/40
# 6/6 [==============================] - 2s 340ms/step - loss: 8.5641e-06 - accuracy: 1.0000 - val_loss: 9.8761 - val_accuracy: 0.4516
# Epoch 11/40
# 6/6 [==============================] - 2s 316ms/step - loss: 5.1823e-06 - accuracy: 1.0000 - val_loss: 10.0259 - val_accuracy: 0.4516
# Epoch 12/40
# 6/6 [==============================] - 2s 320ms/step - loss: 3.5819e-06 - accuracy: 1.0000 - val_loss: 10.1037 - val_accuracy: 0.4516
# Epoch 13/40
# 6/6 [==============================] - 2s 319ms/step - loss: 2.7544e-06 - accuracy: 1.0000 - val_loss: 10.1494 - val_accuracy: 0.4516
# Epoch 14/40
# 6/6 [==============================] - 2s 317ms/step - loss: 2.2929e-06 - accuracy: 1.0000 - val_loss: 10.1746 - val_accuracy: 0.4516
# Epoch 15/40
# 6/6 [==============================] - 2s 343ms/step - loss: 2.0384e-06 - accuracy: 1.0000 - val_loss: 10.1903 - val_accuracy: 0.4516
# Epoch 16/40
# 6/6 [==============================] - 2s 319ms/step - loss: 1.8536e-06 - accuracy: 1.0000 - val_loss: 10.1991 - val_accuracy: 0.4516
# Epoch 17/40
# 6/6 [==============================] - 2s 364ms/step - loss: 1.7361e-06 - accuracy: 1.0000 - val_loss: 10.2045 - val_accuracy: 0.4516
# Epoch 18/40
# 6/6 [==============================] - 3s 415ms/step - loss: 1.6374e-06 - accuracy: 1.0000 - val_loss: 10.2081 - val_accuracy: 0.4516
# Epoch 19/40
# 6/6 [==============================] - 2s 346ms/step - loss: 1.5658e-06 - accuracy: 1.0000 - val_loss: 10.2120 - val_accuracy: 0.4516
# Epoch 20/40
# 6/6 [==============================] - 2s 359ms/step - loss: 1.4747e-06 - accuracy: 1.0000 - val_loss: 10.2151 - val_accuracy: 0.4516
# Epoch 21/40
# 6/6 [==============================] - 2s 322ms/step - loss: 1.3964e-06 - accuracy: 1.0000 - val_loss: 10.2177 - val_accuracy: 0.4516
# Epoch 22/40
# 6/6 [==============================] - 2s 323ms/step - loss: 1.3232e-06 - accuracy: 1.0000 - val_loss: 10.2199 - val_accuracy: 0.4516
# Epoch 23/40
# 6/6 [==============================] - 2s 325ms/step - loss: 1.2661e-06 - accuracy: 1.0000 - val_loss: 10.2205 - val_accuracy: 0.4516
# Epoch 24/40
# 6/6 [==============================] - 2s 383ms/step - loss: 1.2253e-06 - accuracy: 1.0000 - val_loss: 10.2220 - val_accuracy: 0.4516
# Epoch 25/40
# 6/6 [==============================] - 2s 389ms/step - loss: 1.1597e-06 - accuracy: 1.0000 - val_loss: 10.2226 - val_accuracy: 0.4516
# Epoch 26/40
# 6/6 [==============================] - 2s 328ms/step - loss: 1.1205e-06 - accuracy: 1.0000 - val_loss: 10.2243 - val_accuracy: 0.4516
# Epoch 27/40
# 6/6 [==============================] - 2s 324ms/step - loss: 1.0890e-06 - accuracy: 1.0000 - val_loss: 10.2264 - val_accuracy: 0.4516
# Epoch 28/40
# 6/6 [==============================] - 2s 331ms/step - loss: 1.0465e-06 - accuracy: 1.0000 - val_loss: 10.2281 - val_accuracy: 0.4516
# Epoch 29/40
# 6/6 [==============================] - 2s 351ms/step - loss: 9.9794e-07 - accuracy: 1.0000 - val_loss: 10.2295 - val_accuracy: 0.4516
# Epoch 30/40
# 6/6 [==============================] - 2s 330ms/step - loss: 9.8261e-07 - accuracy: 1.0000 - val_loss: 10.2319 - val_accuracy: 0.4516
# Epoch 31/40
# 6/6 [==============================] - 2s 331ms/step - loss: 9.4515e-07 - accuracy: 1.0000 - val_loss: 10.2333 - val_accuracy: 0.4516
# Epoch 32/40
# 6/6 [==============================] - 2s 330ms/step - loss: 9.1279e-07 - accuracy: 1.0000 - val_loss: 10.2342 - val_accuracy: 0.4516
# Epoch 33/40
# 6/6 [==============================] - 2s 330ms/step - loss: 8.8044e-07 - accuracy: 1.0000 - val_loss: 10.2351 - val_accuracy: 0.4516
# Epoch 34/40
# 6/6 [==============================] - 2s 354ms/step - loss: 8.5149e-07 - accuracy: 1.0000 - val_loss: 10.2361 - val_accuracy: 0.4516
# Epoch 35/40
# 6/6 [==============================] - 2s 331ms/step - loss: 8.3531e-07 - accuracy: 1.0000 - val_loss: 10.2374 - val_accuracy: 0.4516
# Epoch 36/40
# 6/6 [==============================] - 2s 334ms/step - loss: 8.0806e-07 - accuracy: 1.0000 - val_loss: 10.2390 - val_accuracy: 0.4516
# Epoch 37/40
# 6/6 [==============================] - 2s 336ms/step - loss: 7.8507e-07 - accuracy: 1.0000 - val_loss: 10.2394 - val_accuracy: 0.4516
# Epoch 38/40
# 6/6 [==============================] - 2s 333ms/step - loss: 7.6719e-07 - accuracy: 1.0000 - val_loss: 10.2407 - val_accuracy: 0.4516
# Epoch 39/40
# 6/6 [==============================] - 2s 358ms/step - loss: 7.4675e-07 - accuracy: 1.0000 - val_loss: 10.2424 - val_accuracy: 0.4516
# Epoch 40/40
# 6/6 [==============================] - 2s 330ms/step - loss: 7.2462e-07 - accuracy: 1.0000 - val_loss: 10.2447 - val_accuracy: 0.4516

# %%
model2_2.save('Model2.2_Related_cropped.h5')

# %% [markdown]
# # Model 3 ResNetV2 50,101,152

# %% [markdown]
# - 50 all output was cow
# - 101 most of the output was cow
# - 152 take 55 minutes to train and 10 minutes to predict

# %%
res = ResNet50V2(include_top=False, weights="imagenet",input_shape=(IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH,3))

for layer in res.layers:
  layer.trainable = False  

# our layers - you can add more if you want
x = Flatten()(res.output)
predictions = Dense(len(folders), activation='softmax')(x)

# create a model object
model3 = Model(inputs = res.input, outputs = predictions)

# view the structure of the model
model3.summary()

# tell the model what cost and optimization method to use
model3.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 350, 350, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 356, 356, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 175, 175, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 177, 177, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 88, 88, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 88, 88, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 88, 88, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 88, 88, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 88, 88, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 88, 88, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 90, 90, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 88, 88, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 88, 88, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 88, 88, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 88, 88, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 88, 88, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 88, 88, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 88, 88, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 88, 88, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 88, 88, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 88, 88, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 88, 88, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 90, 90, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 88, 88, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 88, 88, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 88, 88, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 88, 88, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 88, 88, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 88, 88, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 88, 88, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 88, 88, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 88, 88, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 88, 88, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 90, 90, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 44, 44, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 44, 44, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 44, 44, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 44, 44, 256)  0          ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 44, 44, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 44, 44, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 44, 44, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 44, 44, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 44, 44, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 44, 44, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 44, 44, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 46, 46, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 44, 44, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 44, 44, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 44, 44, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 44, 44, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 44, 44, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 44, 44, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 44, 44, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 44, 44, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 44, 44, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 44, 44, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 44, 44, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 46, 46, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 44, 44, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 44, 44, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 44, 44, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 44, 44, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 44, 44, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 44, 44, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 44, 44, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 44, 44, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 44, 44, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 44, 44, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 46, 46, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 44, 44, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 44, 44, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 44, 44, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 44, 44, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 44, 44, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 44, 44, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 44, 44, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 44, 44, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 44, 44, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 44, 44, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 46, 46, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 22, 22, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 22, 22, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 22, 22, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 22, 22, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 22, 22, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 22, 22, 512)  0           ['max_pooling2d_4[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 22, 22, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 22, 22, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 22, 22, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 24, 24, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 22, 22, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 22, 22, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 22, 22, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 22, 22, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 22, 22, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 22, 22, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 22, 22, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 24, 24, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 22, 22, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 22, 22, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 22, 22, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 22, 22, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 22, 22, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 22, 22, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 24, 24, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 22, 22, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 22, 22, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 22, 22, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 22, 22, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 22, 22, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 22, 22, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 24, 24, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 22, 22, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 22, 22, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 22, 22, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 22, 22, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 22, 22, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 22, 22, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 24, 24, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 22, 22, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 22, 22, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 22, 22, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 22, 22, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 22, 22, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 22, 22, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 22, 22, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 22, 22, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 24, 24, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 11, 11, 256)  589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 11, 11, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 11, 11, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 11, 11, 1024  0          ['conv4_block5_out[0][0]']
#                                 )
#
#  conv4_block6_3_conv (Conv2D)   (None, 11, 11, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_out (Add)         (None, 11, 11, 1024  0           ['max_pooling2d_5[0][0]',
#                                 )                                 'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 11, 11, 1024  4096       ['conv4_block6_out[0][0]']
#  ormalization)                  )
#
#  conv5_block1_preact_relu (Acti  (None, 11, 11, 1024  0          ['conv5_block1_preact_bn[0][0]']
#  vation)                        )
#
#  conv5_block1_1_conv (Conv2D)   (None, 11, 11, 512)  524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 11, 11, 512)  2048       ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 11, 11, 512)  0          ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 13, 13, 512)  0          ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 11, 11, 512)  2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 11, 11, 512)  2048       ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 11, 11, 512)  0          ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 11, 11, 2048  2099200     ['conv5_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 11, 11, 2048  1050624     ['conv5_block1_2_relu[0][0]']
#                                 )
#
#  conv5_block1_out (Add)         (None, 11, 11, 2048  0           ['conv5_block1_0_conv[0][0]',
#                                 )                                 'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 11, 11, 2048  8192       ['conv5_block1_out[0][0]']
#  ormalization)                  )
#
#  conv5_block2_preact_relu (Acti  (None, 11, 11, 2048  0          ['conv5_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv5_block2_1_conv (Conv2D)   (None, 11, 11, 512)  1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 11, 11, 512)  2048       ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 11, 11, 512)  0          ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 13, 13, 512)  0          ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 11, 11, 512)  2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 11, 11, 512)  2048       ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 11, 11, 512)  0          ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 11, 11, 2048  1050624     ['conv5_block2_2_relu[0][0]']
#                                 )
#
#  conv5_block2_out (Add)         (None, 11, 11, 2048  0           ['conv5_block1_out[0][0]',
#                                 )                                 'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 11, 11, 2048  8192       ['conv5_block2_out[0][0]']
#  ormalization)                  )
#
#  conv5_block3_preact_relu (Acti  (None, 11, 11, 2048  0          ['conv5_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv5_block3_1_conv (Conv2D)   (None, 11, 11, 512)  1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 11, 11, 512)  2048       ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 11, 11, 512)  0          ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 13, 13, 512)  0          ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 11, 11, 512)  2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 11, 11, 512)  2048       ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 11, 11, 512)  0          ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 11, 11, 2048  1050624     ['conv5_block3_2_relu[0][0]']
#                                 )
#
#  conv5_block3_out (Add)         (None, 11, 11, 2048  0           ['conv5_block2_out[0][0]',
#                                 )                                 'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 11, 11, 2048  8192        ['conv5_block3_out[0][0]']
#                                 )
#
#  post_relu (Activation)         (None, 11, 11, 2048  0           ['post_bn[0][0]']
#                                 )
#
#  flatten_3 (Flatten)            (None, 247808)       0           ['post_relu[0][0]']
#
#  dense_3 (Dense)                (None, 7)            1734663     ['flatten_3[0][0]']
#
# ==================================================================================================
# Total params: 25,299,463
# Trainable params: 1,734,663
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
hist2 = model3.fit_generator(steps_per_epoch=len(train_dataset), generator=train_dataset, validation_data=validation_dataset, validation_steps=len(validation_dataset), epochs=6)
# Out:
# <ipython-input-18-12a0c716d8ce>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist2 = model3.fit_generator(steps_per_epoch=len(train_dataset), generator=train_dataset, validation_data=validation_dataset, validation_steps=len(validation_dataset), epochs=6)
# Epoch 1/6
# 6/6 [==============================] - 10s 904ms/step - loss: 7.2303 - accuracy: 0.6071 - val_loss: 11.4206 - val_accuracy: 0.7097
# Epoch 2/6
# 6/6 [==============================] - 1s 238ms/step - loss: 2.4199 - accuracy: 0.9071 - val_loss: 9.9261 - val_accuracy: 0.7097
# Epoch 3/6
# 6/6 [==============================] - 2s 264ms/step - loss: 0.5672 - accuracy: 0.9714 - val_loss: 9.9651 - val_accuracy: 0.8065
# Epoch 4/6
# 6/6 [==============================] - 2s 238ms/step - loss: 8.2080e-06 - accuracy: 1.0000 - val_loss: 8.4780 - val_accuracy: 0.8065
# Epoch 5/6
# 6/6 [==============================] - 1s 239ms/step - loss: 3.4060e-09 - accuracy: 1.0000 - val_loss: 8.3904 - val_accuracy: 0.7742
# Epoch 6/6
# 6/6 [==============================] - 1s 238ms/step - loss: 2.5545e-09 - accuracy: 1.0000 - val_loss: 8.6631 - val_accuracy: 0.7742

# %%
model3.save('res50V2_cropped.h5')

# %% [markdown]
# # Model 4 MobileNet

# %%
mobile = MobileNetV2(input_shape=(IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH,3), weights='imagenet', include_top=False)

# don't train existing weights
for layer in mobile.layers:
  layer.trainable = False

# our layers - you can add more if you want
x = Flatten()(mobile.output)
# x = Dense(1000, activation='relu')(x)
prediction = Dense(len(folders), activation='softmax')(x)

# create a model object
model4 = Model(inputs=mobile.input, outputs=prediction)

# view the structure of the model
model4.summary()

# tell the model what cost and optimization method to use
model4.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 350, 350, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 175, 175, 32  864         ['input_3[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 175, 175, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 175, 175, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 175, 175, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 175, 175, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 175, 175, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 175, 175, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 175, 175, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 175, 175, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 175, 175, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 175, 175, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 177, 177, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 88, 88, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 88, 88, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 88, 88, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 88, 88, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 88, 88, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 88, 88, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 88, 88, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 88, 88, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 88, 88, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 88, 88, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 88, 88, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 88, 88, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 88, 88, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 88, 88, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 88, 88, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 88, 88, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 88, 88, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 89, 89, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 44, 44, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 44, 44, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 44, 44, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 44, 44, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 44, 44, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 44, 44, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 44, 44, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 44, 44, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 44, 44, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 44, 44, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 44, 44, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 44, 44, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 44, 44, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 44, 44, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 44, 44, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 44, 44, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 44, 44, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 44, 44, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 44, 44, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 44, 44, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 44, 44, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 44, 44, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 44, 44, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 44, 44, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 44, 44, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 44, 44, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 45, 45, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 22, 22, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 22, 22, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 22, 22, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 22, 22, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 22, 22, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 22, 22, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 22, 22, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 22, 22, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 22, 22, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 22, 22, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 22, 22, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 22, 22, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 22, 22, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 22, 22, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 22, 22, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 22, 22, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 22, 22, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 22, 22, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 22, 22, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 22, 22, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 22, 22, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 22, 22, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 22, 22, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 22, 22, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 22, 22, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 22, 22, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 22, 22, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 22, 22, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 22, 22, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 22, 22, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 22, 22, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 22, 22, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 22, 22, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 22, 22, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 22, 22, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 22, 22, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 22, 22, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 22, 22, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 22, 22, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 22, 22, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 22, 22, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 22, 22, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 22, 22, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 22, 22, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 22, 22, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 22, 22, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 22, 22, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 22, 22, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 22, 22, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 22, 22, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 22, 22, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 22, 22, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 22, 22, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 22, 22, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 22, 22, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 22, 22, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 22, 22, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 22, 22, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 22, 22, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 22, 22, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 22, 22, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 23, 23, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 11, 11, 576)  5184       ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 11, 11, 576)  2304       ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 11, 11, 576)  0          ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 11, 11, 160)  92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 11, 11, 160)  640        ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 11, 11, 960)  153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 11, 11, 960)  3840       ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 11, 11, 960)  0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 11, 11, 960)  8640       ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 11, 11, 960)  3840       ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 11, 11, 960)  0          ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 11, 11, 160)  153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 11, 11, 160)  640        ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 11, 11, 160)  0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 11, 11, 960)  153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 11, 11, 960)  3840       ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 11, 11, 960)  0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 11, 11, 960)  8640       ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 11, 11, 960)  3840       ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 11, 11, 960)  0          ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 11, 11, 160)  153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 11, 11, 160)  640        ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 11, 11, 160)  0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 11, 11, 960)  153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 11, 11, 960)  3840       ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 11, 11, 960)  0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 11, 11, 960)  8640       ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 11, 11, 960)  3840       ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 11, 11, 960)  0          ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 11, 11, 320)  307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 11, 11, 320)  1280       ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 11, 11, 1280  409600      ['block_16_project_BN[0][0]']
#                                 )
#
#  Conv_1_bn (BatchNormalization)  (None, 11, 11, 1280  5120       ['Conv_1[0][0]']
#                                 )
#
#  out_relu (ReLU)                (None, 11, 11, 1280  0           ['Conv_1_bn[0][0]']
#                                 )
#
#  flatten_4 (Flatten)            (None, 154880)       0           ['out_relu[0][0]']
#
#  dense_4 (Dense)                (None, 7)            1084167     ['flatten_4[0][0]']
#
# ==================================================================================================
# Total params: 3,342,151
# Trainable params: 1,084,167
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
hist2 = model4.fit_generator(steps_per_epoch=len(train_dataset), generator=train_dataset, validation_data=validation_dataset, validation_steps=len(validation_dataset), epochs=6)
# Out:
# <ipython-input-21-07a7a248712f>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist2 = model4.fit_generator(steps_per_epoch=len(train_dataset), generator=train_dataset, validation_data=validation_dataset, validation_steps=len(validation_dataset), epochs=6)
# Epoch 1/6
# 6/6 [==============================] - 6s 514ms/step - loss: 4.6150 - accuracy: 0.5857 - val_loss: 2.6548 - val_accuracy: 0.7419
# Epoch 2/6
# 6/6 [==============================] - 1s 160ms/step - loss: 1.0702 - accuracy: 0.9214 - val_loss: 2.8351 - val_accuracy: 0.7097
# Epoch 3/6
# 6/6 [==============================] - 1s 160ms/step - loss: 0.0144 - accuracy: 0.9929 - val_loss: 3.4954 - val_accuracy: 0.8065
# Epoch 4/6
# 6/6 [==============================] - 1s 163ms/step - loss: 0.1387 - accuracy: 0.9786 - val_loss: 2.5921 - val_accuracy: 0.8065
# Epoch 5/6
# 6/6 [==============================] - 1s 166ms/step - loss: 0.0415 - accuracy: 0.9929 - val_loss: 2.0774 - val_accuracy: 0.8065
# Epoch 6/6
# 6/6 [==============================] - 1s 167ms/step - loss: 1.5326e-06 - accuracy: 1.0000 - val_loss: 2.3236 - val_accuracy: 0.8065

# %%
model4.save('mobileV2_cropped.h5')

# %% [markdown]
# # Model 5 InceptionV3

# %%
incept = InceptionV3(input_shape=(IMAGE_HEIGHT_WIDTH,IMAGE_HEIGHT_WIDTH,3), weights='imagenet', include_top=False)

# don't train existing weights
for layer in incept.layers:
  layer.trainable = False

# our layers - you can add more if you want
x = Flatten()(incept.output)

prediction = Dense(len(folders), activation='softmax')(x)

# create a model object
model5 = Model(inputs=incept.input, outputs=prediction)

# view the structure of the model
model5.summary()

# tell the model what cost and optimization method to use
model5.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 350, 350, 3  0           []
#                                 )]
#
#  conv2d_6 (Conv2D)              (None, 174, 174, 32  864         ['input_4[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 174, 174, 32  96         ['conv2d_6[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 174, 174, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 172, 172, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 172, 172, 32  96         ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 172, 172, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 172, 172, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 172, 172, 64  192        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 172, 172, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 85, 85, 64)  0           ['activation_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 85, 85, 80)   5120        ['max_pooling2d_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 85, 85, 80)  240         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 85, 85, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 83, 83, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 83, 83, 192)  576        ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 83, 83, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 41, 41, 192)  0          ['activation_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 41, 41, 64)   12288       ['max_pooling2d_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 41, 41, 64)  192         ['conv2d_14[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 41, 41, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 41, 41, 48)   9216        ['max_pooling2d_7[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 41, 41, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 41, 41, 48)  144         ['conv2d_12[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 41, 41, 96)  288         ['conv2d_15[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 41, 41, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 41, 41, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 41, 41, 192)  0          ['max_pooling2d_7[0][0]']
#  ing2D)
#
#  conv2d_11 (Conv2D)             (None, 41, 41, 64)   12288       ['max_pooling2d_7[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 41, 41, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 41, 41, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 41, 41, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 41, 41, 64)  192         ['conv2d_11[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 41, 41, 64)  192         ['conv2d_13[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 41, 41, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 41, 41, 32)  96          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 41, 41, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 41, 41, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 41, 41, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 41, 41, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 41, 41, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 41, 41, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 41, 41, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 41, 41, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 41, 41, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 41, 41, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 41, 41, 48)  144         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 41, 41, 96)  288         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 41, 41, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 41, 41, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 41, 41, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_18 (Conv2D)             (None, 41, 41, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 41, 41, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 41, 41, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 41, 41, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 41, 41, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 41, 41, 64)  192         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 41, 41, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 41, 41, 64)  192         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 41, 41, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 41, 41, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 41, 41, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 41, 41, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 41, 41, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 41, 41, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 41, 41, 64)  192         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 41, 41, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 41, 41, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 41, 41, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 41, 41, 48)  144         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 41, 41, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 41, 41, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 41, 41, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 41, 41, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_25 (Conv2D)             (None, 41, 41, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 41, 41, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 41, 41, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 41, 41, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 41, 41, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 41, 41, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 41, 41, 96)  288         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 41, 41, 64)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 41, 41, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 41, 41, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 41, 41, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 41, 41, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 41, 41, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 41, 41, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 41, 41, 64)  192         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 41, 41, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 41, 41, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 41, 41, 96)  288         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 41, 41, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 20, 20, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 20, 20, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 20, 20, 384)  1152       ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 20, 20, 96)  288         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 20, 20, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 20, 20, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 20, 20, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 20, 20, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_8[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 20, 20, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 20, 20, 128)  384        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 20, 20, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 20, 20, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 20, 20, 128)  384        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 20, 20, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 20, 20, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 20, 20, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 20, 20, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 20, 20, 128)  384        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 20, 20, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 20, 20, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 20, 20, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 20, 20, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 20, 20, 128)  384        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 20, 20, 128)  384        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 20, 20, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 20, 20, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 20, 20, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_36 (Conv2D)             (None, 20, 20, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 20, 20, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 20, 20, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 20, 20, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 20, 20, 192)  576        ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 20, 20, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 20, 20, 192)  576        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 20, 20, 192)  576        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 20, 20, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 20, 20, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 20, 20, 160)  480        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 20, 20, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 20, 20, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 20, 20, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 20, 20, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 20, 20, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 20, 20, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 20, 20, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 20, 20, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 20, 20, 160)  480        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 20, 20, 160)  480        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 20, 20, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_46 (Conv2D)             (None, 20, 20, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 20, 20, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 20, 20, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 20, 20, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 20, 20, 192)  576        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 20, 20, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 20, 20, 192)  576        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 20, 20, 192)  576        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 20, 20, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 20, 20, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 20, 20, 160)  480        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 20, 20, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 20, 20, 160)  480        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 20, 20, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 20, 20, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 20, 20, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 20, 20, 160)  480        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 20, 20, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 20, 20, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 20, 20, 160)  480        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 20, 20, 160)  480        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 20, 20, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 20, 20, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_56 (Conv2D)             (None, 20, 20, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 20, 20, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 20, 20, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 20, 20, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 20, 20, 192)  576        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 20, 20, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 20, 20, 192)  576        ['conv2d_64[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 20, 20, 192)  576        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 20, 20, 192)  0           ['batch_normalization_58[0][0]']
# ...
#  conv2d_86 (Conv2D)             (None, 9, 9, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 9, 9, 448)   1344        ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 9, 9, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 9, 9, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 9, 9, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 9, 9, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 9, 9, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 9, 9, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 9, 9, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 9, 9, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_82 (Conv2D)             (None, 9, 9, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_84[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_85[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_89[0][0]']
#  ormalization)
#
#  conv2d_90 (Conv2D)             (None, 9, 9, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 9, 9, 320)   960         ['conv2d_82[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 9, 9, 192)   576         ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 9, 9, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 9, 9, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 9, 9, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 9, 9, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 9, 9, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 9, 9, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 9, 9, 448)   1344        ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 9, 9, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 9, 9, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 9, 9, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 9, 9, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 9, 9, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 9, 9, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 9, 9, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 9, 9, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_91 (Conv2D)             (None, 9, 9, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_93[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_94[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_97[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 9, 9, 384)   1152        ['conv2d_98[0][0]']
#  ormalization)
#
#  conv2d_99 (Conv2D)             (None, 9, 9, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 9, 9, 320)   960         ['conv2d_91[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 9, 9, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 9, 9, 192)   576         ['conv2d_99[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 9, 9, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 9, 9, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 9, 9, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 9, 9, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 9, 9, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  flatten_5 (Flatten)            (None, 165888)       0           ['mixed10[0][0]']
#
#  dense_5 (Dense)                (None, 7)            1161223     ['flatten_5[0][0]']
#
# ==================================================================================================
# Total params: 22,964,007
# Trainable params: 1,161,223
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
hist3 = model5.fit_generator(steps_per_epoch=len(train_dataset), generator=train_dataset, validation_data=validation_dataset, validation_steps=len(validation_dataset), epochs=6)
# Out:
# <ipython-input-24-5bb4ef50ac0b>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist3 = model5.fit_generator(steps_per_epoch=len(train_dataset), generator=train_dataset, validation_data=validation_dataset, validation_steps=len(validation_dataset), epochs=6)
# Epoch 1/6
# 6/6 [==============================] - 12s 1s/step - loss: 14.1969 - accuracy: 0.3429 - val_loss: 13.5750 - val_accuracy: 0.5484
# Epoch 2/6
# 6/6 [==============================] - 1s 206ms/step - loss: 4.2708 - accuracy: 0.7929 - val_loss: 8.8206 - val_accuracy: 0.5484
# Epoch 3/6
# 6/6 [==============================] - 1s 201ms/step - loss: 2.5763 - accuracy: 0.8500 - val_loss: 4.5805 - val_accuracy: 0.6774
# Epoch 4/6
# 6/6 [==============================] - 1s 198ms/step - loss: 0.2064 - accuracy: 0.9571 - val_loss: 6.7883 - val_accuracy: 0.7097
# Epoch 5/6
# 6/6 [==============================] - 1s 205ms/step - loss: 0.6332 - accuracy: 0.9500 - val_loss: 7.9349 - val_accuracy: 0.7097
# Epoch 6/6
# 6/6 [==============================] - 1s 202ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 5.0005 - val_accuracy: 0.7419

# %%
model5.save('inceptionV3_cropped.h5')

# %% [markdown]
# # Testing

# %% [markdown]
# ## Cropped Images

# %%
#!pip install mediapipe

# %%
import cv2
import mediapipe as mp
import math


class HandDetector:
    """
    Finds Hands using the mediapipe library. Exports the landmarks
    in pixel format. Adds extra functionalities like finding how
    many fingers are up or the distance between two fingers. Also
    provides bounding box info of the hand found.
    """

    def __init__(self, mode=False, maxHands=2, detectionCon=0.5, minTrackCon=0.5):
        """
        :param mode: In static mode, detection is done on each image: slower
        :param maxHands: Maximum number of hands to detect
        :param detectionCon: Minimum Detection Confidence Threshold
        :param minTrackCon: Minimum Tracking Confidence Threshold
        """
        self.mode = mode
        self.maxHands = maxHands
        self.detectionCon = detectionCon
        self.minTrackCon = minTrackCon

        self.mpHands = mp.solutions.hands
        self.hands = self.mpHands.Hands(static_image_mode=self.mode, max_num_hands=self.maxHands,
                                        min_detection_confidence=self.detectionCon,
                                        min_tracking_confidence=self.minTrackCon)
        self.mpDraw = mp.solutions.drawing_utils
        self.tipIds = [4, 8, 12, 16, 20]
        self.fingers = []
        self.lmList = []

    def findHands(self, img, draw=True, flipType=True):
        """
        Finds hands in a BGR image.
        :param img: Image to find the hands in.
        :param draw: Flag to draw the output on the image.
        :return: Image with or without drawings
        """
        #blank_image = np.zeros((1080,1080,3), np.uint8)
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        self.results = self.hands.process(imgRGB)
        allHands = []
        h, w, c = img.shape
        if self.results.multi_hand_landmarks:
            for handType, handLms in zip(self.results.multi_handedness, self.results.multi_hand_landmarks):
                myHand = {}
                ## lmList
                mylmList = []
                xList = []
                yList = []
                for id, lm in enumerate(handLms.landmark):
                    px, py, pz = int(lm.x * w), int(lm.y * h), int(lm.z * w)
                    mylmList.append([px, py, pz])
                    xList.append(px)
                    yList.append(py)

                ## bbox
                xmin, xmax = min(xList), max(xList)
                ymin, ymax = min(yList), max(yList)
                boxW, boxH = xmax - xmin, ymax - ymin
                bbox = xmin, ymin, boxW, boxH
                cx, cy = bbox[0] + (bbox[2] // 2), \
                         bbox[1] + (bbox[3] // 2)

                myHand["lmList"] = mylmList
                myHand["bbox"] = bbox
                myHand["center"] = (cx, cy)

                if flipType:
                    if handType.classification[0].label == "Right":
                        myHand["type"] = "Left"
                    else:
                        myHand["type"] = "Right"
                else:
                    myHand["type"] = handType.classification[0].label
                allHands.append(myHand)

                ## draw
                if draw:
                    self.mpDraw.draw_landmarks(img, handLms,
                                               self.mpHands.HAND_CONNECTIONS)
#                     cv2.rectangle(img, (bbox[0] - 20, bbox[1] - 20),
#                                   (bbox[0] + bbox[2] + 20, bbox[1] + bbox[3] + 20),
#                                   (255, 0, 255), 2)
#                     cv2.putText(img, myHand["type"], (bbox[0] - 30, bbox[1] - 30), cv2.FONT_HERSHEY_PLAIN,
#                                 2, (255, 0, 255), 2)
        if draw:
            return allHands,img
        else:
            return allHands

    def fingersUp(self, myHand):
        """
        Finds how many fingers are open and returns in a list.
        Considers left and right hands separately
        :return: List of which fingers are up
        """
        myHandType = myHand["type"]
        myLmList = myHand["lmList"]
        if self.results.multi_hand_landmarks:
            fingers = []
            # Thumb
            if myHandType == "Right":
                if myLmList[self.tipIds[0]][0] > myLmList[self.tipIds[0] - 1][0]:
                    fingers.append(1)
                else:
                    fingers.append(0)
            else:
                if myLmList[self.tipIds[0]][0] < myLmList[self.tipIds[0] - 1][0]:
                    fingers.append(1)
                else:
                    fingers.append(0)

            # 4 Fingers
            for id in range(1, 5):
                if myLmList[self.tipIds[id]][1] < myLmList[self.tipIds[id] - 2][1]:
                    fingers.append(1)
                else:
                    fingers.append(0)
        return fingers

    def findDistance(self, p1, p2, img=None):
        """
        Find the distance between two landmarks based on their
        index numbers.
        :param p1: Point1
        :param p2: Point2
        :param img: Image to draw on.
        :param draw: Flag to draw the output on the image.
        :return: Distance between the points
                 Image with output drawn
                 Line information
        """

        x1, y1 = p1
        x2, y2 = p2
        cx, cy = (x1 + x2) // 2, (y1 + y2) // 2
        length = math.hypot(x2 - x1, y2 - y1)
        info = (x1, y1, x2, y2, cx, cy)
        if img is not None:
            cv2.circle(img, (x1, y1), 15, (255, 0, 255), cv2.FILLED)
            cv2.circle(img, (x2, y2), 15, (255, 0, 255), cv2.FILLED)
            cv2.line(img, (x1, y1), (x2, y2), (255, 0, 255), 3)
            cv2.circle(img, (cx, cy), 15, (255, 0, 255), cv2.FILLED)
            return length, info, img
        else:
            return length, info

# %%
detector = HandDetector(maxHands=1)
offset = 20
imgSize = IMAGE_HEIGHT_WIDTH
out_predicitons = []

mydir2 = "/content/drive/MyDrive/Projects/GP Project/Dataset/croppedDataset/testSet"
for i in os.listdir(mydir2):
  img = cv2.imread(mydir2 + "/" + i )
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(img)

  #cv2.imshow("Image",img)

  #print(f"Count:{count} -  {folderPath}/{folder}/{image}")
  imgOutput = img.copy()
  hands, img = detector.findHands(img)
  #cv2.imshow(f"Image{count+1}",img)
  if hands:
      hand = hands[0]
      x, y, w, h = hand['bbox']
      imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255
      imgCrop = img[y - offset:y + h + offset, x - offset:x + w + offset]
      imgCropShape = imgCrop.shape
      aspectRatio = h / w
      if aspectRatio > 1:
          k = imgSize / h
          wCal = math.ceil(k * w)
          imgResize = cv2.resize(imgCrop, (wCal, imgSize))
          imgResizeShape = imgResize.shape
          wGap = math.ceil((imgSize - wCal) / 2)
          imgWhite[:, wGap:wCal + wGap] = imgResize


      else:
          k = imgSize / w
          hCal = math.ceil(k * h)
          imgResize = cv2.resize(imgCrop, (imgSize, hCal))
          imgResizeShape = imgResize.shape
          hGap = math.ceil((imgSize - hCal) / 2)
          imgWhite[hGap:hCal + hGap, :] = imgResize

      cv2.rectangle(imgOutput, (x - offset, y - offset-50),
                    (x - offset+90, y - offset-50+50), (255, 0, 255), cv2.FILLED)
      #Labels are stored in labels lis
      #cv2.putText(imgOutput, labels[index], (x, y -26), cv2.FONT_HERSHEY_COMPLEX, 1.7, (255, 255, 255), 2)
      cv2.rectangle(imgOutput, (x-offset, y-offset),
                    (x + w+offset, y + h+offset), (255, 0, 255), 4)
      #       cv2.imshow("ImageCrop", imgCrop)
      #cv2.imshow("ImageWhite", imgWhite)
      imgWhite = cv2.cvtColor(imgWhite, cv2.COLOR_BGR2RGB)
      plt.imshow(imgWhite)
      plt.show()
      imgWhite = img_to_array(imgWhite)
      imgWhite = imgWhite.reshape((1, imgWhite.shape[0], imgWhite.shape[1], imgWhite.shape[2]))
      imgWhite = preprocess_input(imgWhite)
      print(imgWhite.shape)
      prediction = model.predict(imgWhite).argmax()
      out_predicitons.append(prediction)

      dic = list(train_dataset.class_indices)
      print(dic[prediction])
      
#cv2.waitKey(0)

# %% [markdown]
# ## Regular Size Picture

# %%
my_images_input = []
my_images_labels = []


# getting the testing images output labels
if mode == "ORG":
  for images in glob("/content/drive/MyDrive/Projects/GP Project/Dataset/TestSet/*.png"):
      my_images_input.append(os.path.basename(images).split('.')[0].split('_')[0])
  for current_image in my_images_input:
    [my_images_labels.append(value) for key, value in my_dic.items() if current_image == key]
elif mode == "Crop":
  for images in glob("/content/drive/MyDrive/Projects/GP Project/Dataset/croppedDataset/testSet/*.png"):
      my_images_input.append(os.path.basename(images).split('.')[0].split('_')[0])
  for current_image in my_images_input:
    [my_images_labels.append(value) for key, value in my_dic.items() if current_image == key]
else:
  for images in glob("/content/drive/MyDrive/Projects/GP Project/Dataset/BgRemoved/Testing/*.png"):
    my_images_input.append(os.path.basename(images).split('.')[0].split('_')[0])
  for current_image in my_images_input:
    [my_images_labels.append(value) for key, value in my_dic.items() if current_image == key]

# %%
if mode == "ORG":
  dir_path = "/content/drive/MyDrive/Projects/GP Project/Dataset/TestSet"
elif mode == "Crop":
  dir_path = "/content/drive/MyDrive/Projects/GP Project/Dataset/croppedDataset/testSet"
else: 
  dir_path = "/content/drive/MyDrive/Projects/GP Project/Dataset/BgRemoved/Testing"

out_predicitons = []
for i in os.listdir(dir_path):
    my_image = load_img(dir_path + '//' + i , target_size=(IMAGE_HEIGHT_WIDTH, IMAGE_HEIGHT_WIDTH))

    plt.imshow(my_image)
    plt.show()
    
    #preprocess the image
    my_image = img_to_array(my_image)
    my_image = my_image.reshape((1, my_image.shape[0], my_image.shape[1], my_image.shape[2]))
    my_image = preprocess_input(my_image)

    #make the prediction
    prediction = model.predict(my_image).argmax()
    out_predicitons.append(prediction)

    dic = list(train_dataset.class_indices)
    print(dic[prediction])

#print(confusion_matrix(my_images_labels, out_predicitons))
print(classification_report(my_images_labels, out_predicitons))

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history['loss'], label='train loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# accuracies
plt.plot(hist.history['accuracy'], label='train acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
